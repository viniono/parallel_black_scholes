# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("data/UKX_Calls.csv")
data
# Out:
#       Stock Price  Strike Price  Maturity  Dividends  Volatility  Risk-free  \
# 0     4732.000000           1.0      0.09   0.000000    0.392236     0.0088
# 1     4732.000000           1.0      0.34  11.949099    0.392236     0.0088
# 2     4732.000000           1.0      0.02   0.000000    0.392236     0.0088
# 3     2094.000000           1.0      0.09   0.000000    0.529784     0.0088
# 4     2094.000000           1.0      0.34   4.424667    0.529784     0.0088
# ...           ...           ...       ...        ...         ...        ...
# 1683   241.300003          92.0      1.09   6.926298    0.622848     0.0088
# 1684   241.300003          92.0      0.59   9.061898    0.622848     0.0088
# 1685   241.300003           1.0      0.09   0.000000    0.622848     0.0088
# 1686   241.300003           1.0      0.34   0.000000    0.622848     0.0088
# 1687   241.300003           1.0      0.02   0.000000    0.622848     0.0088
#
#       Call Price
# 0        4731.00
# 1        4731.00
# ...

# %%
data.head(n=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kf/td7j4pms337by229lpg8vb3m0000gn/T/ipykernel_86213/845752024.py in <module>
# ----> 1 data.head(n=5)
#
# NameError: name 'data' is not defined
